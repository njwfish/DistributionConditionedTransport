# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datasets.lineage_tracing import *
from encoder.encoders import DistributionEncoderGNN

# %%
lt = LTSeqDataset()

# %%
enc = DistributionEncoderGNN(in_dim=50, hidden_dim=128, latent_dim=16, set_size=100)
batch = lt[0:2]
z = enc(batch['source_samples'])

# %%
z
# Out:
# tensor([[-0.1049,  0.0825, -0.0545,  0.0735,  0.0426, -0.0826,  0.0235, -0.0247,
#           0.1353, -0.1432,  0.0985, -0.0049,  0.1733, -0.0534, -0.0349,  0.0431],
#         [-0.0879,  0.0966, -0.0098,  0.0696,  0.0457, -0.0915,  0.0143, -0.0209,
#           0.1374, -0.1496,  0.1059, -0.0181,  0.1721, -0.0702, -0.0273,  0.0190]],
#        grad_fn=<EluBackward0>)
